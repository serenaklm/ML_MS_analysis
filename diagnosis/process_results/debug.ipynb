# %%
import os 
from utils import load_pickle

# %%
folder = "../cache/IF_results"
count = 0 

for expt in os.listdir(folder):

    for file in os.listdir(os.path.join(folder, expt)):

        print(file)

        # CF_molsim_con_path = os.path.join(folder, expt, "consistency_peaksCF_molsim_harmful_helpful.pkl")
        # if os.path.exists(CF_molsim_con_path): os.remove(CF_molsim_con_path)
    
    a = z 

    #     peaks_CF_con_path = os.path.join(folder, expt, "peaks_CF_con_helpful_harmful.pkl")
    #     if os.path.exists(peaks_CF_con_path): os.remove(peaks_CF_con_path)

    #     mol_MS_sim_con_path = os.path.join(folder, expt, "mol_MS_sim_con_helpful_harmful.pkl")
    #     if os.path.exists(mol_MS_sim_con_path): os.remove(mol_MS_sim_con_path)
# Out:
# CF_overlap_helpful_harmful.pkl
# MS_sim_helpful_harmful.pkl
# mol_sim_helpful_harmful.pkl
# identical_mol_diff_expt_condition_helpful_harmful_counts.pkl
# identical_mol_helpful_harmful_counts.pkl
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 13
#       8     print(file)
#      10     # CF_molsim_con_path = os.path.join(folder, expt, "consistency_peaksCF_molsim_harmful_helpful.pkl")
#      11     # if os.path.exists(CF_molsim_con_path): os.remove(CF_molsim_con_path)
# ---> 13 a = z
#
# NameError: name 'z' is not defined
