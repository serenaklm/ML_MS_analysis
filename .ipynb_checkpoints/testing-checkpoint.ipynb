# %%
import os
import time
from tqdm import tqdm
from rdkit import Chem
from matchms.importing import load_from_mgf, load_from_msp

from config import * 
from pybatchclassyfire import *

# %%
get_classifications_cf_mod([], par_level = 2)

# %%
def get_all_spectra(path):

    spectra_list = [] 
    if path.endswith(".mgf"): spectrum_generator = load_from_mgf(path, metadata_harmonization = False)
    elif path.endswith(".msp"): spectrum_generator = load_from_msp(path, metadata_harmonization = False)
    else: return []

    for _, spectrum in tqdm(enumerate(spectrum_generator)):
        spectra_list.append(spectrum)
        if _ == 10: break

    return spectra_list

# %%
data_path = os.path.join(final_data_folder, "final_MS.msp")
smiles = [s.metadata["smiles"] for s in get_all_spectra(data_path)]
# Out:
# 100it [00:00, 1963.37it/s]

# %%
get_classifications_cf_mod(smiles, par_level = 2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_classifications_cf_mod(smiles, par_level = 2)
#
# File ~\anaconda3\envs\chem\lib\site-packages\pybatchclassyfire\pybatchclassyfire.py:540, in get_classifications_cf_mod(all_inchi_keys, par_level)
#     531 def get_classifications_cf_mod(all_inchi_keys, par_level):
#     532     """a slightly modified version of the original get_classification() which will take list object as input
#     533
#     534     :param all_inchi_keys: a list of inchikeys
#    (...)
#     537     :type par_level: numeric integer
#     538     """
# --> 540     all_json = run_parallel_job(get_structure_class_entity, all_inchi_keys, parallelism_level = par_level)
#     542     open("all_json.json", "w").write(json.dumps(all_json))
#
# ...
